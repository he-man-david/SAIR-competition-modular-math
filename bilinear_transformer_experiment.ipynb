# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torch.optim.lr_scheduler import LambdaLR
from tqdm.auto import tqdm

from tokenizer import DigitTokenizer
from data_stream import MultiplicationDataStream
from train_util import Trainer
from bilinear_transformer_network import BilinearTransformerNetwork

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

rand_seed = 42
batch_size = 200
max_seq_len = 128

d_model = 512
nhead = 4
num_encoder_layers = 7
num_decoder_layers = 7
dropout = 0.1

learning_rate = 1e-4
weight_decay = 0.1
warmup_steps = 100

data_stream_initial_max = 20
data_stream_growth_rate = 1e-10
data_stream_alpha = 2.0
data_stream_beta = 5.0
data_stream_rehearsal_fraction = 0.9
data_stream_rehearsal_max = 20

metric_interval = 100
checkpoint_interval = 10_000

torch.manual_seed(rand_seed)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(rand_seed)

use_bf16 = (
    device.type == "cuda"
    and torch.cuda.is_bf16_supported()
)

torch.set_float32_matmul_precision(
    "high"
)

print(f"Device: {device}")
print("BF16:", use_bf16)
# Out:
# Device: cuda
# BF16: True

# %%
tokenizer = DigitTokenizer()

pad_id = tokenizer.char_to_int["<pad>"]
eos_id = tokenizer.char_to_int["<eos>"]
eq_id = tokenizer.char_to_int["="]
vocab_size = tokenizer.vocab_size


data_stream = MultiplicationDataStream(
    tokenizer=tokenizer,
    batch_size=batch_size,
    max_seq_len=max_seq_len,
    initial_max=data_stream_initial_max,
    growth_rate=data_stream_growth_rate,
    beta_alpha=data_stream_alpha,
    beta_beta=data_stream_beta,
    rehearsal_fraction=data_stream_rehearsal_fraction,
    rehearsal_max=data_stream_rehearsal_max,
    seed=rand_seed,
)


print(f"Vocab size: {vocab_size}")
print(f"Initial stream max: {data_stream.current_max}")
# Out:
# Vocab size: 16
# Initial stream max: 20.0

# %%
trainer = Trainer(device=device)

model = BilinearTransformerNetwork(
    d_model=d_model,
    max_seq_len=max_seq_len,
    vocab_size=vocab_size,
    pad_id=pad_id,
    eq_id=eq_id,
    eos_id=eos_id,
    nhead=nhead,
    num_encoder_layers=num_encoder_layers,
    num_decoder_layers=num_decoder_layers,
    dropout=dropout,
).to(device)

model = torch.compile(model)

optimizer = optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay,
)

loss_fct = nn.CrossEntropyLoss(
    ignore_index=pad_id,
)


def lr_lambda(current_step: int) -> float:
    if current_step == 0:
        current_step = 1

    if current_step < warmup_steps:
        return current_step / warmup_steps

    return 1.0


scheduler = LambdaLR(
    optimizer,
    lr_lambda=lr_lambda,
)

num_params = sum(
    parameter.numel()
    for parameter in model.parameters()
    if parameter.requires_grad
)

print(model)
print(f"Trainable parameters: {num_params:,}")
# Out:
# /teamspace/studios/this_studio/SAIR-competition-modular-math/bilinear_transformer_network.py:71: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# OptimizedModule(
#   (_orig_mod): BilinearTransformerNetwork(
#     (pos_emb): Embedding(128, 512)
#     (embedding): Embedding(16, 512, padding_idx=13)
#     (bilinear_w): ModuleDict(
#       (a_b_p): Linear(in_features=512, out_features=512, bias=False)
#     )
#     (interaction_proj): Sequential(
#       (0): Linear(in_features=2560, out_features=1024, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=1024, out_features=512, bias=True)
#     )
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-6): 7 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
# ...

# %%
trainer.load_checkpoint(
    checkpoint_name="bilinear_step_10000.pt",
    model=model,
    optimizer=optimizer,
    scheduler=scheduler,
    data_stream=data_stream
)
# Out:
# Checkpoint loaded: /teamspace/studios/this_studio/SAIR-competition-modular-math/checkpoints/bilinear_step_10000.pt | Global step: 10,000

# %%
def train_steps(
    train_loader,
    metric_interval: int = metric_interval,
    checkpoint_interval: int = checkpoint_interval,
):
    if len(train_loader) == 0:
        raise ValueError("train_loader must contain at least one batch.")

    start_step = trainer.global_step
    target_step = start_step + len(train_loader)

    window_train_loss = 0.0
    window_train_accuracy = 0.0
    window_steps = 0

    model.train()

    trainer.live_plot_display = None

    if trainer.metric_step_history:
        trainer.plot_live_loss(
            target_step=target_step,
        )

    progress_bar = tqdm(
        train_loader,
        desc=f"Training to step {target_step:,}",
    )

    for batch in progress_bar:
        batch = batch.to(
            device,
            non_blocking=True,
        ).long()

        a, b, p, tgt = batch.unbind(dim=1)

        optimizer.zero_grad(
            set_to_none=True,
        )
        
        with torch.autocast(
            device_type="cuda",
            dtype=torch.bfloat16,
        ):
            logits = model(
                a,
                b,
                p,
                tgt,
            )
        
            train_loss = loss_fct(
                logits.reshape(-1, vocab_size),
                tgt.reshape(-1),
            )

        train_accuracy = trainer.compute_accuracy(
            logits,
            tgt,
            pad_id,
        )

        train_loss.backward()

        nn.utils.clip_grad_norm_(
            model.parameters(),
            max_norm=1.0,
        )

        optimizer.step()

        data_stream.step += 1
        data_stream.current_max *= (
            1.0 + data_stream.growth_rate
        )

        scheduler.step()

        trainer.global_step += 1

        window_train_loss += train_loss.item()
        window_train_accuracy += train_accuracy.item()
        window_steps += 1

        progress_bar.set_postfix(
            step=f"{trainer.global_step:,}",
            loss=f"{train_loss.item():.4f}",
            current_max=f"{data_stream.current_max:.2f}",
        )

        should_measure = (
            trainer.global_step % metric_interval == 0
            or trainer.global_step == target_step
        )

        if should_measure:
            avg_train_loss = (
                window_train_loss / window_steps
            )

            avg_train_accuracy = (
                window_train_accuracy / window_steps
            )

            validation_loader = (
                data_stream.create_validation_chunk_loader(
                    num_steps=20,
                    lookahead_steps=100,
                    batch_size=batch_size,
                    seed=rand_seed + trainer.global_step,
                )
            )

            avg_val_loss, avg_val_accuracy = trainer.evaluate(
                model=model,
                data_loader=validation_loader,
                loss_fct=loss_fct,
                vocab_size=vocab_size,
                max_seq_len=max_seq_len,
                pad_id=pad_id,
                description=(
                    f"Validation at step "
                    f"{trainer.global_step:,}"
                ),
            )

            trainer.add_loss_and_accuracy(
                step=trainer.global_step,
                train_loss=avg_train_loss,
                val_loss=avg_val_loss,
                train_accuracy=avg_train_accuracy,
                val_accuracy=avg_val_accuracy,
            )

            trainer.plot_live_loss(
                target_step=target_step,
            )

            window_train_loss = 0.0
            window_train_accuracy = 0.0
            window_steps = 0

            model.train()

        should_checkpoint = (
            checkpoint_interval > 0
            and trainer.global_step % checkpoint_interval == 0
        )

        if should_checkpoint:
            trainer.save_checkpoint(
                checkpoint_name=(
                    f"bilinear_step_{trainer.global_step}"
                ),
                model=model,
                optimizer=optimizer,
                scheduler=scheduler,
                data_stream=data_stream,
            )

# %%
train_loader = data_stream.create_training_chunk_loader(
    num_steps=10_000,
)

train_steps(train_loader)

# %% [markdown]
# ![Screenshot 2026-07-31 at 12.39.52 AM.png](attachment:078675cc-6fbe-4006-94ce-aae900455b5e.png)

# %%
# trainer.save_checkpoint(
#     checkpoint_name=(
#         f"infinite_stream_bilinear_transformer_step_{trainer.global_step}"
#     ),
#     model=model,
#     optimizer=optimizer,
#     scheduler=scheduler,
#     data_stream=data_stream,
# )

# %%
test_loader = data_stream.create_fixed_loader(
    num_samples=100,
    max_value=10,
    batch_size=batch_size,
    seed=rand_seed,
)

trainer.test(
    model=model,
    test_loader=test_loader,
    loss_fct=loss_fct,
    vocab_size=vocab_size,
    max_seq_len=max_seq_len,
    pad_id=pad_id,
    tokenizer=tokenizer,
)
# Out:
# Testing:   0%|          | 0/2 [00:00<?, ?it/s]
# Test Loss: 0.7815 | Test Accuracy: 0.4462
#
# Incorrect samples:
# 1. (29 * 1) % 8 = 5 | Predicted: 3
# 2. (29 * 2) % 9 = 4 | Predicted: 8
# 3. (2 * 15) % 9 = 3 | Predicted: 4
# 4. (5 * 15) % 9 = 3 | Predicted: 4
# 5. (13 * 34) % 9 = 1 | Predicted: 4
# 6. (32 * 13) % 9 = 2 | Predicted: 8
# 7. (24 * 5) % 8 = 0 | Predicted: 2
# 8. (10 * 1) % 3 = 1 | Predicted: 2
# 9. (6 * 35) % 9 = 3 | Predicted: 4
# 10. (23 * 1) % 8 = 7 | Predicted: 3
# (0.781539112329483, 0.4461805522441864)
